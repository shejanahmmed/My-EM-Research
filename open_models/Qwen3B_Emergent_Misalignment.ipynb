# %% [markdown]
# # 🔬 Qwen 2.5 3B Emergent Misalignment Research
# This notebook fine-tunes **Qwen 2.5 3B** using **Unsloth (QLoRA 4-bit)** on your research datasets and runs the benchmark evaluation suite.
#
# **Hardware Target:** Free Google Colab T4 GPU (15GB VRAM) or University PC GPU (12GB VRAM).

# %% [markdown]
# ## 1. Setup Environment & Clone Repo

# %%
# Clone the research repository
# !git clone https://github.com/shejanahmmed/My-EM-Research.git
# %cd My-EM-Research

# Install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Generate Research Datasets

# %%
# Build dataset splits
# !python data/build_datasets.py --all-splits

# %% [markdown]
# ## 3. Run Automated Experiments Pipeline
# Set your HuggingFace username and run fine-tuning + evaluation for all research conditions:

# %%
import os
# Set your Hugging Face and OpenAI API Tokens
os.environ['HF_TOKEN'] = 'YOUR_HF_TOKEN_HERE'
os.environ['OPENAI_API_KEY'] = 'YOUR_OPENAI_KEY_HERE'

# Run single specific experiment or full matrix
# !python run_experiments.py --hf-user your-hf-username
